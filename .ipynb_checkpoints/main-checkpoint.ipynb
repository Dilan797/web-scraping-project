# %%
import pandas as pd

# %%
todas_tablas = pd.read_html('https://fbref.com/es/equipos/054efa67/2024-2025/Estadisticas-de-Bayern-Munich')
df = todas_tablas[0]    
df
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Jugador               País               Posc
# 0        Joshua Kimmich             de GER                 CC
# 1            Harry Kane            eng ENG                 DL
# 2         Michael Olise             fr FRA              DL,CC
# 3           Kim Min-jae             kr KOR                 DF
# 4          Manuel Neuer             de GER                 PO
# 5         Jamal Musiala             de GER                 CC
# 6       Dayot Upamecano             fr FRA                 DF
# 7         Konrad Laimer             at AUT                 DF
# 8     Raphaël Guerreiro             pt POR              DF,CC
# 9   Aleksandar Pavlovic             de GER                 CC
# 10           Leroy Sané             de GER                 DL
# 11      Alphonso Davies             ca CAN                 DF
# 12            Eric Dier            eng ENG                 DF
# ...

# %%
#Aca tomamos las descripciones de cada columna, la cual es la primera fila
df.columns
# Out:
# Index(['Jugador', 'País', 'Posc', 'Edad', 'PJ', 'Titular', 'Mín', '90 s',
#        'Gls.', 'Ass', 'G+A', 'G-TP', 'TP', 'TPint', 'TA', 'TR', 'xG', 'npxG',
#        'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'PrgR', 'Gls.', 'Ast', 'G+A', 'G-TP',
#        'G+A-TP', 'xG', 'xAG', 'xG+xAG', 'npxG', 'npxG+xAG', 'Partidos'],
#       dtype='object')

# %%
df_jugadores
# Out:
# Index(['Jugador', 'País', 'Posc', 'Edad', 'PJ', 'Titular', 'Mín', '90 s',
#        'Gls.', 'Ass', 'G+A', 'G-TP', 'TP', 'TPint', 'TA', 'TR', 'xG', 'npxG',
#        'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'PrgR', 'Gls.', 'Ast', 'G+A', 'G-TP',
#        'G+A-TP', 'xG', 'xAG', 'xG+xAG', 'npxG', 'npxG+xAG', 'Partidos'],
#       dtype='object')
